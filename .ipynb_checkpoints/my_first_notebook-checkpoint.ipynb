# %%
import sys
sys.path.append('/opt/conda/lib/python3.9/site-packages')
import lxml
from csw_sdk import DataDiscovery
discovery = DataDiscovery.DataDiscovery()
collections = discovery.getDataCollections()
for collection in collections.list:
    print (collection.name)
    print (collection.mission)
# Out:
# AGGREGATED_POTENTIAL_FISHING_EFFORT
# NA_
# AIS_ESH_F_SA
# AIS
# AIS_FISH_ARE
# S3_
# AIS_FISH_FPR
# AIS
# AIS_FISH_TRI
# AIS
# ARIA3_BACKSHORELINES
# NA_
# ARIA3_BATHYMETRY_SAMPLES
# S2
# ARIA3_BUILDINGS_PONTA_DELGADA
# NA_
# ARIA3_CLASS_SOLENT
# NA_
# ARIA3_COASTAL_EXPOSURE_INDEX
# NA_
# ARIA3_COASTLINES
# NA_
# ARIA3_HISTORICAL_ATM_POLLUTION
# S5P
# ARIA3_HISTORICAL_PART_MATTER
# NA_
# ARIA3_HISTORICAL_WAV_CURR_MSL
# NA_
# ARIA3_IMG_SOLENT
# NA_
# ARIA3_LABEL_SOLENT
# NA_
# ARIA3_LAND_USE
# NA_
# ARIA3_LAND_USE_CHANGE
# NA_
# ARIA3_LAND_USE_CLMS
# NA_
# ARIA3_NRT_FORECAST_ATM_POLLUTION
# S5P
# ARIA3_NRT_FORECAST_PART_MATTER
# NA_
# ARIA3_NRT_FORECAST_WAV_CURR_MSL
# NA_
# ARIA3_PDA_DEM_COPERNICUS
# NA_
# ARIA3_PDA_EUROPEAN_SETTLEMENT_MAP
# NA_
# ARIA3_PDA_ORBVIEW_IMAGES
# NA_
# ARIA3_PDA_S2_2021
# S2
# ARIA3_PDE_ECIMP_REPORT
# NA_
# ARIA3_PDE_OPENSTREETMAP
# NA_
# ARIA3_PDE_PCA_REPORT
# NA_
# ARIA3_PORT_INFRASTRUCTURES_PONTA_DELGADA
# NA_
# ARIA3_SPATIAL_MEAN_ATM_PART_MATTER
# NA_
# ...

# %%
print(discovery)

# %%
collection_name = 'S2__VITONDVI'
collection_mission = 'S2_'
datasets = discovery.search(filters={'mission':collection_mission, 'product_type':collection_name})

# %%
print(datasets.results)
# Out:
# [{identifier=None, title=S2__20220417_000000_FDEA01F3_VITONDVI, start_time=2022-04-17T00:00:00, stop_time=2022-04-17T00:00:00, spatial=None, quicklook=None, url=https://data-lake.services4eo.com/storage/21a83e1c-a094-4602-bf59-8baf95447ffd/output/S2__20220417_000000_FDEA01F3_VITONDVI}, {identifier=None, title=S2__20220415_000000_FBE1287A_VITONDVI, start_time=2022-04-15T00:00:00, stop_time=2022-04-15T00:00:00, spatial=None, quicklook=None, url=https://data-lake.services4eo.com/storage/21a83e1c-a094-4602-bf59-8baf95447ffd/output/S2__20220415_000000_FBE1287A_VITONDVI}, {identifier=None, title=S2__20220412_000000_48CCD3D5_VITONDVI, start_time=2022-04-12T00:00:00, stop_time=2022-04-12T00:00:00, spatial=None, quicklook=None, url=https://data-lake.services4eo.com/storage/21a83e1c-a094-4602-bf59-8baf95447ffd/output/S2__20220412_000000_48CCD3D5_VITONDVI}, {identifier=None, title=S2__20220411_000000_D4B7DCAF_VITONDVI, start_time=2022-04-11T00:00:00, stop_time=2022-04-11T00:00:00, spatial=None,
# ...
